# %% [markdown]
# <a href="https://colab.research.google.com/github/Bregella/Bregella/blob/main/BigQueryCase4_predict2610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'my-project-021022-364315' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
# Запуск этого кода отобразит запрос, использованный для создания предыдущего задания.

job = client.get_job('bquxjob_1f0c2770_184139783f0') # Идентификатор задания, вставленный на основе результатов запроса, выбранного для изучения
print(job.query)
# Out:
# SELECT
# *
#  FROM
#
#   ML.PREDICT(MODEL `my-project-021022-364315.AC.case`,
#     (
#       SELECT
#       *
#     FROM
#       `my-project-021022-364315.AC.train_case_1`))

# %%
# Запуск этого кода будет считывать результаты предыдущей работы.

job = client.get_job('bquxjob_1f0c2770_184139783f0') # Идентификатор задания, вставленный на основе результатов запроса, выбранных для изучения
results = job.to_dataframe()
results
# Out:
#       predicted_Sales                 OrderDate  Order_Quantity  \
# 0         6910.914129 2015-12-25 00:00:00+00:00               9
# 1        27879.267827 2016-08-19 00:00:00+00:00               9
# 2         6699.129260 2014-12-13 00:00:00+00:00              10
# 3        19842.625531 2016-12-08 00:00:00+00:00              10
# 4         7932.621927 2015-12-30 00:00:00+00:00              10
# ...               ...                       ...             ...
# 6387     10685.630879 2014-06-21 00:00:00+00:00               9
# 6388      9959.156561 2016-12-27 00:00:00+00:00               9
# 6389     39287.831241 2014-07-27 00:00:00+00:00               9
# 6390     27669.491704 2014-11-26 00:00:00+00:00               9
# 6391     17061.334547 2015-04-20 00:00:00+00:00               9
#
#       Total_Unit_Cost   OrderNumber      Channel Warehouse_Code    Sales  \
# 0             188.404  SO - 0004901    Wholesale         AXW291   2291.4
# ...

# %% [markdown]
# Посмотрим описательную статистику. Описательная статистика включает те параметры, которые обобщают центральную тенденцию, дисперсию и форму распределения набора данных.

# %%
results.describe()
# Out:
#        predicted_Sales  Order_Quantity  Total_Unit_Cost         Sales
# count      6392.000000     6392.000000      6392.000000   6392.000000
# mean      16187.522174        7.676001      1437.466332  17602.579193
# std        8927.843346        1.847071      1118.848438  14032.667630
# min         817.338252        5.000000        68.675000    837.500000
# 25%        9878.912571        6.000000       608.527500   7175.700000
# 50%       13826.035075        8.000000      1080.576000  13031.500000
# 75%       20563.587259        9.000000      2059.647000  24607.425000
# max       52565.231103       11.000000      5498.556000  71562.700000

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6392 entries, 0 to 6391
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   predicted_Sales  6392 non-null   float64
#  1   OrderDate        6392 non-null   datetime64[ns, UTC]
#  2   Order_Quantity   6392 non-null   int64
#  3   Total_Unit_Cost  6392 non-null   float64
#  4   OrderNumber      6392 non-null   object
#  5   Channel          6392 non-null   object
#  6   Warehouse_Code   6392 non-null   object
#  7   Sales            6392 non-null   float64
#  8   Country          6392 non-null   object
#  9   Region_Group     6392 non-null   object
#  10  Customer_Names   6392 non-null   object
#  11  Product_Name     6392 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(3), int64(1), object(7)
# memory usage: 599.4+ KB

# %% [markdown]
# Ссылка на отчет в Google Studio https://datastudio.google.com/embed/reporting/1b191394-5074-450f-9f05-952bedfbbd92/page/tEnnC

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
